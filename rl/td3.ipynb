# %%
import numpy as np

from stable_baselines3 import TD3
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import (
    NormalActionNoise,
    OrnsteinUhlenbeckActionNoise,
)
from stable_baselines3.common.env_util import make_vec_env
from src.callback import TrainingCallback, env_callback, env_callback_value

# %%
env = env_callback_value()
n_actions = env.action_space.shape[-1]
vec_env = make_vec_env(env_callback_value, n_envs=8)

model = TD3(
    "MlpPolicy",
    vec_env,
    action_noise=OrnsteinUhlenbeckActionNoise(
        mean=np.zeros(n_actions),
        sigma=0.1 * np.ones(n_actions),
    ),
    verbose=0,
    tensorboard_log="results",
)

# %%
# to load already trained model
# model = TD3.load("models/TD3_32000_steps")

model.env = vec_env

model.learn(
    total_timesteps=100000,
    callback=[
        TrainingCallback(1000, env),
        CheckpointCallback(1000, "models", name_prefix="TD3"),
    ],
)
# Out:
# Timestep: 53000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       1 # to load already trained model
#       2 # model = TD3.load("models/TD3_32000_steps")
#       4 model.env = vec_env
# ----> 6 model.learn(
#       7     total_timesteps=100000,
#       8     callback=[
#       9         TrainingCallback(1000, env),
#      10         CheckpointCallback(1000, "models", name_prefix="TD3"),
#      11     ],
#      12 )
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\td3\td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:568, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     566 callback.update_locals(locals())
#     567 # Only stop training if return value is False, not when it is None.
# --> 568 if not callback.on_step():
#     569     return RolloutReturn(num_collected_steps * env.num_envs, num_collected_episodes, continue_training=False)
#     571 # Retrieve reward and episode length if using Monitor wrapper
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\callbacks.py:114, in BaseCallback.on_step(self)
#     111 self.n_calls += 1
#     112 self.num_timesteps = self.model.num_timesteps
# --> 114 return self._on_step()
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\callbacks.py:219, in CallbackList._on_step(self)
#     216 continue_training = True
#     217 for callback in self.callbacks:
#     218     # Return False (stop training) if at least one callback returns False
# --> 219     continue_training = callback.on_step() and continue_training
#     220 return continue_training
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\callbacks.py:114, in BaseCallback.on_step(self)
#     111 self.n_calls += 1
#     112 self.num_timesteps = self.model.num_timesteps
# --> 114 return self._on_step()
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\src\callback.py:48, in TrainingCallback._on_step(self)
#      46 def _on_step(self):
#      47     if self.num_timesteps % self.performance_checkpoint_freq == 0:
# ---> 48         evaluate_pricing_agent(self.env, self.model, 500)
#      49         cprint(f"\nTimestep: {self.num_timesteps}")
#      50     return True
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\src\eval.py:19, in evaluate_pricing_agent(env, model, n)
#      16 done = False
#      18 while not done:
# ---> 19     action, _ = model.predict(state)
#      20     next_state, reward, done, _, _ = env.step(action)
#      21     state = next_state
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\td3\policies.py:242, in TD3Policy._predict(self, observation, deterministic)
#     239 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#     240     # Note: the deterministic deterministic parameter is ignored in the case of TD3.
#     241     #   Predictions are always deterministic.
# --> 242     return self.actor(observation)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\td3\policies.py:77, in Actor.forward(self, obs)
#      75 def forward(self, obs: th.Tensor) -> th.Tensor:
#      76     # assert deterministic, 'The TD3 actor only outputs deterministic actions'
# ---> 77     features = self.extract_features(obs, self.features_extractor)
#      78     return self.mu(features)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\policies.py:131, in BaseModel.extract_features(self, obs, features_extractor)
#     123 """
#     124 Preprocess the observation if needed and extract features.
#     125
#    (...)
#     128 :return: The extracted features
#     129 """
#     130 preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 131 return features_extractor(preprocessed_obs)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\stable_baselines3\common\torch_layers.py:45, in FlattenExtractor.forward(self, observations)
#      44 def forward(self, observations: th.Tensor) -> th.Tensor:
# ---> 45     return self.flatten(observations)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\SamuelAtkins\projects\deepSOC\rl\.venv\lib\site-packages\torch\nn\modules\flatten.py:49, in Flatten.forward(self, input)
#      48 def forward(self, input: Tensor) -> Tensor:
# ---> 49     return input.flatten(self.start_dim, self.end_dim)
#
# KeyboardInterrupt:
